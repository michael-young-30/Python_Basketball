# %% [markdown]
# <a href="https://colab.research.google.com/github/michael-young-30/Python_Basketball/blob/main/data_munging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# %pip install nba_api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.9/254.9 KB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 70.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.24.1 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.1 which is incompatible.
# ...

# %%
from nba_api.stats import endpoints

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=endpoints.leagueleaders.LeagueLeaders(season= '2021-22').league_leaders.get_data_frame()

# %%
data.head(10)
# Out:
#    PLAYER_ID  RANK                 PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 0    1629027     1             Trae Young  1610612737  ATL  76  2652  711
# 1     201942     2          DeMar DeRozan  1610612741  CHI  76  2743  774
# 2     203954     3            Joel Embiid  1610612755  PHI  68  2296  666
# 3    1628369     4           Jayson Tatum  1610612738  BOS  76  2731  708
# 4     203999     5           Nikola Jokic  1610612743  DEN  74  2476  764
# 5     203507     6  Giannis Antetokounmpo  1610612749  MIL  67  2204  689
# 6    1629029     7            Luka Doncic  1610612742  DAL  65  2301  641
# 7    1626164     8           Devin Booker  1610612756  PHX  68  2345  662
# 8    1626157     9     Karl-Anthony Towns  1610612750  MIN  74  2475  642
# 9    1628378    10       Donovan Mitchell  1610612762  UTA  67  2266  617
#
#     FGA  FG_PCT  ...   REB  AST  STL  BLK  TOV   PF   PTS   EFF  AST_TOV  \
# 0  1544   0.460  ...   284  737   72    7  303  128  2155  2066     2.43
# ...

# %%
pd.set_option('display.max.columns',None)

# %%
eff = data.loc[:,:'EFF']

# %%
eff.head(10)
# Out:
#    PLAYER_ID  RANK                 PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 0    1629027     1             Trae Young  1610612737  ATL  76  2652  711
# 1     201942     2          DeMar DeRozan  1610612741  CHI  76  2743  774
# 2     203954     3            Joel Embiid  1610612755  PHI  68  2296  666
# 3    1628369     4           Jayson Tatum  1610612738  BOS  76  2731  708
# 4     203999     5           Nikola Jokic  1610612743  DEN  74  2476  764
# 5     203507     6  Giannis Antetokounmpo  1610612749  MIL  67  2204  689
# 6    1629029     7            Luka Doncic  1610612742  DAL  65  2301  641
# 7    1626164     8           Devin Booker  1610612756  PHX  68  2345  662
# 8    1626157     9     Karl-Anthony Towns  1610612750  MIN  74  2475  642
# 9    1628378    10       Donovan Mitchell  1610612762  UTA  67  2266  617
#
#     FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB   REB  AST  \
# ...

# %%
data.columns
# Out:
# Index(['PLAYER_ID', 'RANK', 'PLAYER', 'TEAM_ID', 'TEAM', 'GP', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'EFF',
#        'AST_TOV', 'STL_TOV'],
#       dtype='object')

# %%
data['PLAYER'].head(10)
# Out:
# 0               Trae Young
# 1            DeMar DeRozan
# 2              Joel Embiid
# 3             Jayson Tatum
# 4             Nikola Jokic
# 5    Giannis Antetokounmpo
# 6              Luka Doncic
# 7             Devin Booker
# 8       Karl-Anthony Towns
# 9         Donovan Mitchell
# Name: PLAYER, dtype: object

# %%
data.loc[0,:].head(10)
# Out:
# PLAYER_ID       1629027
# RANK                  1
# PLAYER       Trae Young
# TEAM_ID      1610612737
# TEAM                ATL
# GP                   76
# MIN                2652
# FGM                 711
# FGA                1544
# FG_PCT             0.46
# Name: 0, dtype: object

# %%
data['TEAM'].unique()
# Out:
# array(['ATL', 'CHI', 'PHI', 'BOS', 'DEN', 'MIL', 'DAL', 'PHX', 'MIN',
#        'UTA', 'LAL', 'BKN', 'GSW', 'CHA', 'MEM', 'TOR', 'CLE', 'NYK',
#        'SAS', 'OKC', 'NOP', 'SAC', 'MIA', 'DET', 'IND', 'LAC', 'HOU',
#        'ORL', 'WAS', 'POR'], dtype=object)

# %%
gsw_df = data.loc[data['TEAM']=='GSW']
gsw_df.head(10)
# Out:
#      PLAYER_ID  RANK            PLAYER     TEAM_ID TEAM  GP   MIN  FGM   FGA  \
# 13      201939    14     Stephen Curry  1610612744  GSW  64  2211  535  1224
# 26     1629673    27      Jordan Poole  1610612744  GSW  76  2283  474  1058
# 48      203952    49    Andrew Wiggins  1610612744  GSW  73  2330  475  1019
# 164    1630228   165  Jonathan Kuminga  1610612744  GSW  70  1185  236   460
# 165     202691   165     Klay Thompson  1610612744  GSW  32   941  246   573
# 220     203490   221   Otto Porter Jr.  1610612744  GSW  63  1396  193   416
# 223    1627780   224    Gary Payton II  1610612744  GSW  71  1248  212   344
# 227    1626172   228      Kevon Looney  1610612744  GSW  82  1732  208   364
# 237    1627814   238        Damion Lee  1610612744  GSW  63  1257  169   383
# 249     202357   250   Nemanja Bjelica  1610612744  GSW  71  1142  160   342
#
#      FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  \
# ...

# %%
gsw_df.sort_values(by = 'MIN', ascending=False)
# Out:
#      PLAYER_ID  RANK                  PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 48      203952    49          Andrew Wiggins  1610612744  GSW  73  2330  475
# 26     1629673    27            Jordan Poole  1610612744  GSW  76  2283  474
# 13      201939    14           Stephen Curry  1610612744  GSW  64  2211  535
# 227    1626172   228            Kevon Looney  1610612744  GSW  82  1732  208
# 220     203490   221         Otto Porter Jr.  1610612744  GSW  63  1396  193
# 282     203110   283          Draymond Green  1610612744  GSW  46  1329  135
# 237    1627814   238              Damion Lee  1610612744  GSW  63  1257  169
# 223    1627780   224          Gary Payton II  1610612744  GSW  71  1248  212
# 164    1630228   165        Jonathan Kuminga  1610612744  GSW  70  1185  236
# 249     202357   250         Nemanja Bjelica  1610612744  GSW  71  1142  160
# 312    1629308   313   Juan Toscano-Anderson  1610612744  GSW  73   994  115
# ...

# %%
gsw_df['FG3M'].min()
# Out:
# 0

# %%
data['TEAM'].value_counts()
# Out:
# OKC    26
# DET    25
# POR    24
# WAS    23
# MEM    22
# BOS    22
# PHX    22
# CLE    22
# ORL    21
# MIA    21
# NYK    21
# ATL    21
# DAL    21
# LAL    21
# SAC    20
# DEN    20
# IND    20
# TOR    20
# UTA    20
# CHI    20
# MIL    19
# PHI    19
# SAS    18
# NOP    18
# MIN    17
# CHA    17
# BKN    17
# LAC    16
# HOU    16
# GSW    16
# Name: TEAM, dtype: int64

# %%
data.groupby(['TEAM']).count()['PLAYER_ID']
# Out:
# TEAM
# ATL    21
# BKN    17
# BOS    22
# CHA    17
# CHI    20
# CLE    22
# DAL    21
# DEN    20
# DET    25
# GSW    16
# HOU    16
# IND    20
# LAC    16
# LAL    21
# MEM    22
# MIA    21
# MIL    19
# MIN    17
# NOP    18
# NYK    21
# OKC    26
# ORL    21
# PHI    19
# PHX    22
# POR    24
# SAC    20
# SAS    18
# TOR    20
# UTA    20
# WAS    23
# Name: PLAYER_ID, dtype: int64

# %%
data.groupby('TEAM')['FG3M'].sum().sort_values(ascending=False)
# Out:
# TEAM
# UTA    1228
# MIN    1211
# GSW    1176
# LAC    1167
# MIL    1152
# CHA    1142
# DAL    1139
# NYK    1130
# MIA    1129
# DEN    1116
# BOS    1054
# HOU    1037
# TOR    1036
# IND    1019
# PHX    1011
# LAL    1010
# ATL    1005
# OKC     993
# ORL     981
# PHI     956
# CLE     949
# MEM     945
# SAC     930
# POR     907
# NOP     885
# BKN     876
# DET     876
# CHI     876
# SAS     875
# WAS     787
# Name: FG3M, dtype: int64

# %%
gsw_df['PTSRANK'] = gsw_df['PTS'].rank(ascending=False)
gsw_df['PTSRANK']
# Out:
# <ipython-input-61-4b13463c0f3f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gsw_df['PTSRANK'] = gsw_df['PTS'].rank(ascending=False)
# 13      1.0
# 26      2.0
# 48      3.0
# 164     4.5
# 165     4.5
# 220     6.0
# 223     7.0
# 227     8.0
# 237     9.0
# 249    10.0
# 282    11.0
# 312    12.0
# 342    13.0
# 409    14.0
# 452    15.0
# 495    16.0
# Name: PTSRANK, dtype: float64

# %%
gsw_df
# Out:
#      PLAYER_ID  RANK                  PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 13      201939    14           Stephen Curry  1610612744  GSW  64  2211  535
# 26     1629673    27            Jordan Poole  1610612744  GSW  76  2283  474
# 48      203952    49          Andrew Wiggins  1610612744  GSW  73  2330  475
# 164    1630228   165        Jonathan Kuminga  1610612744  GSW  70  1185  236
# 165     202691   165           Klay Thompson  1610612744  GSW  32   941  246
# 220     203490   221         Otto Porter Jr.  1610612744  GSW  63  1396  193
# 223    1627780   224          Gary Payton II  1610612744  GSW  71  1248  212
# 227    1626172   228            Kevon Looney  1610612744  GSW  82  1732  208
# 237    1627814   238              Damion Lee  1610612744  GSW  63  1257  169
# 249     202357   250         Nemanja Bjelica  1610612744  GSW  71  1142  160
# 282     203110   283          Draymond Green  1610612744  GSW  46  1329  135
# ...

# %%
gsw_df.loc[(gsw_df['GP']>70) & (gsw_df['FTM']>100)]
# Out:
#     PLAYER_ID  RANK          PLAYER     TEAM_ID TEAM  GP   MIN  FGM   FGA  \
# 26    1629673    27    Jordan Poole  1610612744  GSW  76  2283  474  1058
# 48     203952    49  Andrew Wiggins  1610612744  GSW  73  2330  475  1019
#
#     FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  \
# 26   0.448   211   580    0.364  246  266   0.925    34   226  260  304   60
# 48   0.466   157   399    0.393  149  235   0.634    85   240  325  161   76
#
#     BLK  TOV   PF   PTS   EFF  AST_TOV  STL_TOV  PTSRANK
# 26   23  187  206  1405  1261     1.63     0.32      2.0
# 48   51  111  158  1256  1128     1.45     0.69      3.0
